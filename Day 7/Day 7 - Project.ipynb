# %% [markdown]
# # Step1 - Launching

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
data = pd.read_csv("E:\LetsUpgrade-AI-ML\Assignments\Day 7\general_data.csv",sep=",")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      4410 non-null   int64
#  1   Attrition                4410 non-null   object
#  2   BusinessTravel           4410 non-null   object
#  3   Department               4410 non-null   object
#  4   DistanceFromHome         4410 non-null   int64
#  5   Education                4410 non-null   int64
#  6   EducationField           4410 non-null   object
#  7   EmployeeCount            4410 non-null   int64
#  8   EmployeeID               4410 non-null   int64
#  9   Gender                   4410 non-null   object
#  10  JobLevel                 4410 non-null   int64
#  11  JobRole                  4410 non-null   object
#  12  MaritalStatus            4410 non-null   object
#  13  MonthlyIncome            4410 non-null   int64
# ...

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
data.shape
# Out:
# (4410, 24)

# %%
print(data.columns)
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# # Step 2 - Data Treatment:

# %%
#data Cleaning
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeID                  0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
data.isnull().any()
# Out:
# Age                        False
# Attrition                  False
# BusinessTravel             False
# Department                 False
# DistanceFromHome           False
# Education                  False
# EducationField             False
# EmployeeCount              False
# EmployeeID                 False
# Gender                     False
# JobLevel                   False
# JobRole                    False
# MaritalStatus              False
# MonthlyIncome              False
# NumCompaniesWorked          True
# Over18                     False
# PercentSalaryHike          False
# StandardHours              False
# StockOptionLevel           False
# TotalWorkingYears           True
# TrainingTimesLastYear      False
# YearsAtCompany             False
# YearsSinceLastPromotion    False
# YearsWithCurrManager       False
# dtype: bool

# %%
data.fillna(0,inplace =True)

# %%
data.isnull().any()    # No Null value
# Out:
# Age                        False
# Attrition                  False
# BusinessTravel             False
# Department                 False
# DistanceFromHome           False
# Education                  False
# EducationField             False
# EmployeeCount              False
# EmployeeID                 False
# Gender                     False
# JobLevel                   False
# JobRole                    False
# MaritalStatus              False
# MonthlyIncome              False
# NumCompaniesWorked         False
# Over18                     False
# PercentSalaryHike          False
# StandardHours              False
# StockOptionLevel           False
# TotalWorkingYears          False
# TrainingTimesLastYear      False
# YearsAtCompany             False
# YearsSinceLastPromotion    False
# YearsWithCurrManager       False
# dtype: bool

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.drop_duplicates()
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %% [markdown]
# # Step 3 – Univariate Analysis

# %% [markdown]
# #### Describe

# %%
print("Describe All Metrics")
dataset3=data[['Age','DistanceFromHome','Education','MonthlyIncome', 'NumCompaniesWorked', 'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].describe().T
dataset3
# Out:
# Describe All Metrics
#                           count          mean           std      min      25%  \
# Age                      4410.0     36.923810      9.133301     18.0     30.0
# DistanceFromHome         4410.0      9.192517      8.105026      1.0      2.0
# Education                4410.0      2.912925      1.023933      1.0      2.0
# MonthlyIncome            4410.0  65029.312925  47068.888559  10090.0  29110.0
# NumCompaniesWorked       4410.0      2.683220      2.499737      0.0      1.0
# PercentSalaryHike        4410.0     15.209524      3.659108     11.0     12.0
# TotalWorkingYears        4410.0     11.256916      7.790928      0.0      6.0
# TrainingTimesLastYear    4410.0      2.799320      1.288978      0.0      2.0
# YearsAtCompany           4410.0      7.008163      6.125135      0.0      3.0
# YearsSinceLastPromotion  4410.0      2.187755      3.221699      0.0      0.0
# YearsWithCurrManager     4410.0      4.123129      3.567327      0.0      2.0
#
# ...

# %% [markdown]
# #### Median

# %%
print("Median")
dataset3=data[['Age','DistanceFromHome','Education','MonthlyIncome', 'NumCompaniesWorked', 'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].median()
dataset3
# Out:
# Median
# Age                           36.0
# DistanceFromHome               7.0
# Education                      3.0
# MonthlyIncome              49190.0
# NumCompaniesWorked             2.0
# PercentSalaryHike             14.0
# TotalWorkingYears             10.0
# TrainingTimesLastYear          3.0
# YearsAtCompany                 5.0
# YearsSinceLastPromotion        1.0
# YearsWithCurrManager           3.0
# dtype: float64

# %% [markdown]
# #### Mode

# %%
print("Mode")
dataset3=data[['Age','DistanceFromHome','Education','MonthlyIncome', 'NumCompaniesWorked', 'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].mode()
dataset3
# Out:
# Mode
#    Age  DistanceFromHome  Education  MonthlyIncome  NumCompaniesWorked  \
# 0   35                 2          3          23420                 1.0
#
#    PercentSalaryHike  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 11               10.0                      2
#
#    YearsAtCompany  YearsSinceLastPromotion  YearsWithCurrManager
# 0               5                        0                     2

# %% [markdown]
# #### Variance

# %%
print("Variance")
dataset3=data[['Age','DistanceFromHome','Education','MonthlyIncome', 'NumCompaniesWorked', 'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].var()
dataset3
# Out:
# Variance
# Age                        8.341719e+01
# DistanceFromHome           6.569144e+01
# Education                  1.048438e+00
# MonthlyIncome              2.215480e+09
# NumCompaniesWorked         6.248686e+00
# PercentSalaryHike          1.338907e+01
# TotalWorkingYears          6.069855e+01
# TrainingTimesLastYear      1.661465e+00
# YearsAtCompany             3.751728e+01
# YearsSinceLastPromotion    1.037935e+01
# YearsWithCurrManager       1.272582e+01
# dtype: float64

# %% [markdown]
# #### Skewness

# %%
print("Skewness")
dataset3=data[['Age','DistanceFromHome','Education','MonthlyIncome', 'NumCompaniesWorked', 'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].skew()
dataset3
# Out:
# Skewness
# Age                        0.413005
# DistanceFromHome           0.957466
# Education                 -0.289484
# MonthlyIncome              1.368884
# NumCompaniesWorked         1.029836
# PercentSalaryHike          0.820569
# TotalWorkingYears          1.113489
# TrainingTimesLastYear      0.552748
# YearsAtCompany             1.763328
# YearsSinceLastPromotion    1.982939
# YearsWithCurrManager       0.832884
# dtype: float64

# %% [markdown]
# #### Kurtosis

# %%
print("Kurtosis")
dataset3=data[['Age','DistanceFromHome','Education','MonthlyIncome', 'NumCompaniesWorked', 'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].kurt()
dataset3
# Out:
# Kurtosis
# Age                       -0.405951
# DistanceFromHome          -0.227045
# Education                 -0.560569
# MonthlyIncome              1.000232
# NumCompaniesWorked         0.015084
# PercentSalaryHike         -0.302638
# TotalWorkingYears          0.909606
# TrainingTimesLastYear      0.491149
# YearsAtCompany             3.923864
# YearsSinceLastPromotion    3.601761
# YearsWithCurrManager       0.167949
# dtype: float64

# %%
box_plot=data.Age
plt.boxplot(box_plot)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2a36c03c608>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2a36c052ec8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2a36c044a48>],
#  'medians': [<matplotlib.lines.Line2D at 0x2a36c060b88>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2a36c052408>],
#  'means': []}

# %% [markdown]
# #### Age is normally distributed without any outliers

# %%
box_plot=data.MonthlyIncome
plt.boxplot(box_plot)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2a36c0f1d88>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2a36c0f1f08>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2a36c0f1588>],
#  'medians': [<matplotlib.lines.Line2D at 0x2a36c0f5f08>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2a36c0f5f88>],
#  'means': []}

# %% [markdown]
# #### Monthly Income is Right skewed with several outliers

# %%
box_plot=data.YearsAtCompany
plt.boxplot(box_plot)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2a36c162e08>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2a36c166dc8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2a36c1623c8>],
#  'medians': [<matplotlib.lines.Line2D at 0x2a36c16bd48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2a36c16be48>],
#  'means': []}

# %% [markdown]
# ### Years at company is also Right Skewed with several outliers observed.

# %% [markdown]
# # Step 4 - Corelation

# %% [markdown]
# #### Corelation before converting categorical data to numerical data

# %%
print(data['Over18'].unique())
# Out:
# ['Y']

# %%
data.drop(['EmployeeCount','EmployeeID','StandardHours','Over18'],axis=1,inplace=True)

# %%
corr_cols = data[['Age','Attrition','BusinessTravel','DistanceFromHome','Education', 'EducationField','Gender', 'JobLevel', 'JobRole',
       'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked',
       'PercentSalaryHike', 'StockOptionLevel', 'TotalWorkingYears',
       'TrainingTimesLastYear', 'YearsAtCompany', 'YearsSinceLastPromotion',
       'YearsWithCurrManager']]

# %%
corr = corr_cols.corr()
plt.figure(figsize=(16,10))
sns.heatmap(corr,annot=True)
plt.show()

# %%
data1 = data.copy()
data1.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  Gender  JobLevel                    JobRole  \
# 0          2  Life Sciences  Female         1  Healthcare Representative
# 1          1  Life Sciences  Female         1         Research Scientist
# 2          4          Other    Male         4            Sales Executive
# 3          5  Life Sciences    Male         3            Human Resources
# 4          1        Medical    Male         1            Sales Executive
#
# ...

# %%
#Convert all the Categorical data into numerical data
print(data1['BusinessTravel'].unique())
print(data1['EducationField'].unique())
print(data1['Gender'].unique())
print(data1['Department'].unique())
print(data1['JobRole'].unique())
print(data1['MaritalStatus'].unique())
# Out:
# ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# ['Female' 'Male']
# ['Sales' 'Research & Development' 'Human Resources']
# ['Healthcare Representative' 'Research Scientist' 'Sales Executive'
#  'Human Resources' 'Research Director' 'Laboratory Technician'
#  'Manufacturing Director' 'Sales Representative' 'Manager']
# ['Married' 'Single' 'Divorced']

# %%
from sklearn.preprocessing import LabelEncoder
labelEncoder_X = LabelEncoder()
data1['BusinessTravel'] = labelEncoder_X.fit_transform(data1['BusinessTravel'])
data1['Department'] = labelEncoder_X.fit_transform(data1['Department'])
data1['EducationField'] = labelEncoder_X.fit_transform(data1['EducationField'])
data1['Gender'] = labelEncoder_X.fit_transform(data1['Gender'])
data1['JobRole'] = labelEncoder_X.fit_transform(data1['JobRole'])
data1['MaritalStatus'] = labelEncoder_X.fit_transform(data1['MaritalStatus'])

# %%
#Print the data after converting all the Categorical data into numerical data
print(data1['BusinessTravel'].unique())
print(data1['EducationField'].unique())
print(data1['Gender'].unique())
print(data1['Department'].unique())
print(data1['JobRole'].unique())
print(data1['MaritalStatus'].unique())
# Out:
# [2 1 0]
# [1 4 3 2 5 0]
# [0 1]
# [2 1 0]
# [0 6 7 1 5 2 4 8 3]
# [1 2 0]

# %%
#Attriton is dependent var
from sklearn.preprocessing import LabelEncoder
label_encoder_y=LabelEncoder()
data1['Attrition']=label_encoder_y.fit_transform(data['Attrition'])

# %%
data1.head()
# Out:
#    Age  Attrition  BusinessTravel  Department  DistanceFromHome  Education  \
# 0   51          0               2           2                 6          2
# 1   31          1               1           1                10          1
# 2   32          0               1           1                17          4
# 3   38          0               0           1                 2          5
# 4   32          0               2           1                10          1
#
#    EducationField  Gender  JobLevel  JobRole  MaritalStatus  MonthlyIncome  \
# 0               1       0         1        0              1         131160
# 1               1       0         1        6              2          41890
# 2               4       1         4        7              1         193280
# 3               1       1         3        1              1          83210
# 4               3       1         1        7              2          23420
#
# ...

# %% [markdown]
# #### Corelation after converting categorical data to numerical data

# %%
data1.describe(include='all').T
# Out:
#                           count          mean           std      min      25%  \
# Age                      4410.0     36.923810      9.133301     18.0     30.0
# Attrition                4410.0      0.161224      0.367780      0.0      0.0
# BusinessTravel           4410.0      1.607483      0.665304      0.0      1.0
# Department               4410.0      1.260544      0.527673      0.0      1.0
# DistanceFromHome         4410.0      9.192517      8.105026      1.0      2.0
# Education                4410.0      2.912925      1.023933      1.0      2.0
# EducationField           4410.0      2.247619      1.331067      0.0      1.0
# Gender                   4410.0      0.600000      0.489954      0.0      0.0
# JobLevel                 4410.0      2.063946      1.106689      1.0      1.0
# JobRole                  4410.0      4.458503      2.461263      0.0      2.0
# MaritalStatus            4410.0      1.097279      0.729955      0.0      1.0
# ...

# %%
corr_cols = data1[['Age','Attrition','BusinessTravel','DistanceFromHome','Education', 'EducationField','Gender', 'JobLevel', 'JobRole',
       'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked',
       'PercentSalaryHike', 'StockOptionLevel', 'TotalWorkingYears',
       'TrainingTimesLastYear', 'YearsAtCompany', 'YearsSinceLastPromotion',
       'YearsWithCurrManager']]

# %%
corr = corr_cols.corr()
plt.figure(figsize=(18,10))
sns.heatmap(corr, annot = True)
plt.show()

# %%
print(len(data))
print(len(data[data['Attrition']=='Yes']))
print(len(data[data['Attrition']=='No']))
print("percentage of yes Attrition is:",(len(data[data['Attrition']=='Yes'])/len(data))*100,"%")
print("percentage of no Attrition is:",(len(data[data['Attrition']=='No'])/len(data))*100,"%")
# Out:
# 4410
# 711
# 3699
# percentage of yes Attrition is: 16.122448979591837 %
# percentage of no Attrition is: 83.87755102040816 %

# %%
sns.countplot(x = "Attrition",data=data)
plt.show()

# %%
sns.countplot(x = "Attrition",data=data,hue="Gender")
plt.show()

# %%
sns.countplot(x = "Attrition",data=data,hue="JobLevel")
plt.show()

# %%
#function to creat group of ages, this helps because we have 78 differente values here

def Age(dataframe):
    dataframe.loc[dataframe['Age'] <= 30,'Age'] = 1
    dataframe.loc[(dataframe['Age'] > 30) & (dataframe['Age'] <= 40), 'Age'] = 2
    dataframe.loc[(dataframe['Age'] > 40) & (dataframe['Age'] <= 50), 'Age'] = 3
    dataframe.loc[(dataframe['Age'] > 50) & (dataframe['Age'] <= 60), 'Age'] = 4
    return dataframe

Age(data1);

# %%
sns.countplot(x = "Attrition",data=data1,hue="Age")
plt.show()

# %%
from scipy.stats import pearsonr

for col_name in data.columns:
    if(data[col_name].dtype == 'object'):
        data[col_name]= data[col_name].astype('category')
        data[col_name] = data[col_name].cat.codes

for col_name1 in data.columns:
    stats, p = pearsonr(data.Attrition, data[col_name1])
    if stats ==0:
        sign=""
    elif stats>0:
        sign = "+ve"
    else:
        sign = "-ve"
    if abs(stats)>=0.7:
        coreln = "Strong "+sign+" corelation"
    elif abs(stats)<0.7 and abs(stats)>0.4:
        coreln = "Moderate "+sign+" corelation"
    elif abs(stats)<=0.4 and abs(stats)>0:
        coreln = "Weak "+sign+" corelation"
    else:
        coreln = "No corelation"
    print("Column =",col_name1,":","r value:",stats,"p value:",p,"--Corelation:",coreln)
    plt.scatter(data.Attrition,data[col_name1])
    plt.xlabel="Attrition"
    plt.ylabel=col_name1
    plt.show()
# Out:
# Column = Age : r value: -0.15920500686577965 p value: 1.996801615886744e-26 --Corelation: Weak -ve corelation
# Column = Attrition : r value: 0.9999999999999994 p value: 0.0 --Corelation: Strong +ve corelation
# Column = BusinessTravel : r value: 7.3776946022246e-05 p value: 0.9960919945437704 --Corelation: Weak +ve corelation
# Column = Department : r value: -0.04820581991834007 p value: 0.0013638319632107141 --Corelation: Weak -ve corelation
# Column = DistanceFromHome : r value: -0.00973014101017966 p value: 0.5182860428050771 --Corelation: Weak -ve corelation
# Column = Education : r value: -0.015111167710968711 p value: 0.3157293177118575 --Corelation: Weak -ve corelation
# Column = EducationField : r value: -0.05794031241568039 p value: 0.00011819790920714883 --Corelation: Weak -ve corelation
# Column = Gender : r value: 0.01812507887701024 p value: 0.22881970951795952 --Corelation: Weak +ve corelation
# ...

# %%
data = pd.read_csv("E:\LetsUpgrade-AI-ML\Assignments\Day 7\general_data.csv",sep=",")

# %%
# Lets look Age of people who have left Organisation
attrition_age=data.loc[data['Attrition']=='Yes'].groupby('Age')['Attrition'].count()\
.plot(kind='line',figsize=(20,10),title='Age wise Attrition')

# %% [markdown]
# ### High number of People between age of 25 and 35 have left an Organisation with max being at age of 29 and 31

# %%
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(20,7))
sns.countplot(x='Attrition',data=data,hue='JobLevel',ax=ax1)
sns.countplot(x='Attrition',data=data,hue='Gender',ax=ax2)

# %% [markdown]
# ### Majority of People after Job Level 2 have left firm.

# %%
sns.pairplot(data[['Age','MonthlyIncome','DistanceFromHome','Attrition']],hue = 'Attrition')

# %%
sns.pairplot(data[['Age','MonthlyIncome','DistanceFromHome','Gender']],hue = 'Gender',hue_order=['Male','Female'], palette={'Male':'black','Female':'magenta'},plot_kws={'alpha':0.1},height=4)

# %% [markdown]
# ### The youngest employee is 18 years old.
# ### The oldest employee is 60 years old.
# ### The range of ages in the company: 42

# %%
print('Frequency of travels (in %): \n')
print(round(data['BusinessTravel'].value_counts(normalize = True)*100,2))
print('\nAttrition rate by Frequency of travels \n')
print(round(data['BusinessTravel'][data['Attrition'] == 'Yes'].value_counts()/data['BusinessTravel'].value_counts()*100,2))
# Out:
# Frequency of travels (in %):
#
# Travel_Rarely        70.95
# Travel_Frequently    18.84
# Non-Travel           10.20
# Name: BusinessTravel, dtype: float64
#
# Attrition rate by Frequency of travels
#
# Travel_Rarely        14.96
# Travel_Frequently    24.91
# Non-Travel            8.00
# Name: BusinessTravel, dtype: float64

# %% [markdown]
# ### Employees who travel frequently are more likely to leave the company

# %%
print('Number of Employees in department (in %): \n')
print(round(data['Department'].value_counts(normalize = True)*100,2))  
print('\nAttrition rate by Department \n')
print(round(data['Department'][data['Attrition'] == 'Yes'].value_counts()/data['Department'].value_counts()*100,2))
# Out:
# Number of Employees in department (in %):
#
# Research & Development    65.37
# Sales                     30.34
# Human Resources            4.29
# Name: Department, dtype: float64
#
# Attrition rate by Department
#
# Research & Development    15.71
# Sales                     15.02
# Human Resources           30.16
# Name: Department, dtype: float64

# %% [markdown]
# ### Employees in Human Resources Department are more likely to leave the company

# %%
print('Number of Employees by Education Level (in %): \n')
print(round(data['Education'].value_counts(normalize = True)*100,2).sort_index())
print('\nAttrition rate by Education Level: \n')
print(round(data['Education'][data['Attrition'] == 'Yes'].value_counts()/data['Education'].value_counts()*100,2).sort_index())
# Out:
# Number of Employees by Education Level (in %):
#
# 1    11.56
# 2    19.18
# 3    38.91
# 4    27.07
# 5     3.27
# Name: Education, dtype: float64
#
# Attrition rate by Education Level:
#
# 1    15.29
# 2    18.79
# 3    15.56
# 4    15.58
# 5    14.58
# Name: Education, dtype: float64

# %% [markdown]
# ### There is no visible corelation between Education Level and Attrition

# %%
print('Number of Employees by Education Field (in %): \n')
print(round(data['EducationField'].value_counts(normalize = True)*100,2).sort_index())

print('\nAttrition rate by Education Field: \n')
print(round(data['EducationField'][data['Attrition'] == 'Yes'].value_counts()/data['EducationField'].value_counts()*100,2).sort_index())
# Out:
# Number of Employees by Education Field (in %):
#
# Human Resources      1.84
# Life Sciences       41.22
# Marketing           10.82
# Medical             31.56
# Other                5.58
# Technical Degree     8.98
# Name: EducationField, dtype: float64
#
# Attrition rate by Education Field:
#
# Human Resources     40.74
# Life Sciences       16.67
# Marketing           15.72
# Medical             16.16
# Other               12.20
# Technical Degree    11.36
# Name: EducationField, dtype: float64

# %% [markdown]
# ### Employees having specialization in Human Resources are more likey to leave the company

# %%
fig = plt.figure(figsize=(15,12))
fig.subplots_adjust(top=0.85, wspace=0.7,hspace = 0.6)

ax1 = fig.add_subplot(2,2,1)
ax1.set_title("Percentage share of employees coming from \ndifferent fields of educations, by department")
sns.heatmap(pd.crosstab(data.Department, data.EducationField, normalize = 'columns'),
            cmap="coolwarm", annot=True, cbar=False, center=0.5)



ax2 = fig.add_subplot(2,2,2)
ax2.set_title("Percentage share of employees coming from \ndifferent fields of educations, by JobRole")
sns.heatmap(pd.crosstab(data.JobRole, data.EducationField, normalize = 'columns'),
            cmap="coolwarm", annot=True, cbar=False, center=0.5)

# %%
print('\nAttrition rate by Marital Status: \n')
print(round(data['MaritalStatus'][data['Attrition'] == 'Yes'].value_counts()/data['MaritalStatus'].value_counts()*100,2))
(data['MaritalStatus'][data['Attrition'] == 'Yes'].value_counts()/data['MaritalStatus'].value_counts()*100).plot.bar(color = 'blue')
# Out:
# Attrition rate by Marital Status:
#
# Divorced    10.09
# Married     12.48
# Single      25.53
# Name: MaritalStatus, dtype: float64

# %% [markdown]
# ### Employees who are single are more likely to leave the company

# %%
print('\nAttrition rate by Total number of companies the employee has worked for: \n')
print(round(data['NumCompaniesWorked'][data['Attrition'] == 'Yes'].value_counts()/data['NumCompaniesWorked'].value_counts()*100,2))

(data['NumCompaniesWorked'][data['Attrition'] == 'Yes'].value_counts()/data['NumCompaniesWorked'].value_counts()*100).plot.bar(color = 'blue')
# Out:
# Attrition rate by Total number of companies the employee has worked for:
#
# 0.0    11.77
# 1.0    18.81
# 2.0    10.96
# 3.0    10.13
# 4.0    12.05
# 5.0    24.60
# 6.0    23.08
# 7.0    22.97
# 8.0    12.24
# 9.0    23.08
# Name: NumCompaniesWorked, dtype: float64

# %% [markdown]
# ### Employees who have worked in large number of companies are more likely to quit the company

# %%
print('\Attrition rate by Salary Hike in %: \n')
print(round(data['PercentSalaryHike'][data['Attrition'] == 'Yes'].value_counts()/data['PercentSalaryHike'].value_counts()*100,2))

(data['PercentSalaryHike'][data['Attrition'] == 'Yes'].value_counts()/data['PercentSalaryHike'].value_counts()*100).plot.bar(color = 'blue')
# Out:
# \Attrition rate by Salary Hike in %:
#
# 11    14.29
# 12    15.15
# 13    16.27
# 14    14.43
# 15    20.79
# 16    12.82
# 17    18.29
# 18    14.61
# 19    18.42
# 20    16.36
# 21    18.75
# 22    17.86
# 23    17.86
# 24    14.29
# 25    27.78
# Name: PercentSalaryHike, dtype: float64

# %% [markdown]
# ### Employees with highest salary hike have left the company

# %%
print('Number of Employees by JobRole (in %): \n')
print(round(data['JobRole'].value_counts(normalize = True)*100,2).sort_index())

print('\nAttrition rate by JobRole: \n')
print(round(data['JobRole'][data['Attrition'] == 'Yes'].value_counts()/data['JobRole'].value_counts()*100,2).sort_index())

(data['JobRole'][data['Attrition'] == 'Yes'].value_counts()/data['JobRole'].value_counts()*100).plot.bar(color = 'blue')
# Out:
# Number of Employees by JobRole (in %):
#
# Healthcare Representative     8.91
# Human Resources               3.54
# Laboratory Technician        17.62
# Manager                       6.94
# Manufacturing Director        9.86
# Research Director             5.44
# Research Scientist           19.86
# Sales Executive              22.18
# Sales Representative          5.65
# Name: JobRole, dtype: float64
#
# Attrition rate by JobRole:
#
# Healthcare Representative    14.50
# Human Resources              13.46
# Laboratory Technician        16.22
# Manager                      13.73
# Manufacturing Director       11.03
# Research Director            23.75
# Research Scientist           18.15
# Sales Executive              16.87
# Sales Representative         14.46
# Name: JobRole, dtype: float64

# %% [markdown]
# ### Employees in Research Director role are more likely to quit the organization

# %%
print('Number of Employees by StockOptionLevel (in %): \n')
print(round(data['StockOptionLevel'].value_counts(normalize = True)*100,2).sort_index())

print('\nAttrition rate by StockOptionLevel: \n')
print(round(data['StockOptionLevel'][data['Attrition'] == 'Yes'].value_counts()/data['StockOptionLevel'].value_counts()*100,2).sort_index())

(data['StockOptionLevel'][data['Attrition'] == 'Yes'].value_counts()/data['StockOptionLevel'].value_counts()*100).plot.bar(color = 'blue')
# Out:
# Number of Employees by StockOptionLevel (in %):
#
# 0    42.93
# 1    40.54
# 2    10.75
# 3     5.78
# Name: StockOptionLevel, dtype: float64
#
# Attrition rate by StockOptionLevel:
#
# 0    16.80
# 1    15.10
# 2    17.72
# 3    15.29
# Name: StockOptionLevel, dtype: float64

# %% [markdown]
# ### There is no corelation between Stock Options and Attrition rate

# %%
print('Number of Employees by TrainingTimesLastYear (in %): \n')
print(round(data['TrainingTimesLastYear'].value_counts(normalize = True)*100,2).sort_index())

print('\nAttrition rate by TrainingTimesLastYear: \n')
print(round(data['TrainingTimesLastYear'][data['Attrition'] == 'Yes'].value_counts()/data['TrainingTimesLastYear'].value_counts()*100,2).sort_index())

(data['TrainingTimesLastYear'][data['Attrition'] == 'Yes'].value_counts()/data['TrainingTimesLastYear'].value_counts()*100).plot.bar(color = 'blue')
# Out:
# Number of Employees by TrainingTimesLastYear (in %):
#
# 0     3.67
# 1     4.83
# 2    37.21
# 3    33.40
# 4     8.37
# 5     8.10
# 6     4.42
# Name: TrainingTimesLastYear, dtype: float64
#
# Attrition rate by TrainingTimesLastYear:
#
# 0    18.52
# 1    14.08
# 2    17.18
# 3    17.52
# 4    13.01
# 5    14.29
# 6     6.15
# Name: TrainingTimesLastYear, dtype: float64

# %% [markdown]
# ### Employees with less training are more likely to quit

# %%
print('Number of Employees by YearsSinceLastPromotion (in %): \n')
print(round(data['YearsSinceLastPromotion'].value_counts(normalize = True)*100,2).sort_index())

print('\nAttrition rate by YearsSinceLastPromotion: \n')
print(round(data['YearsSinceLastPromotion'][data['Attrition'] == 'Yes'].value_counts()/data['YearsSinceLastPromotion'].value_counts()*100,2).sort_index())

(data['YearsSinceLastPromotion'][data['Attrition'] == 'Yes'].value_counts()/data['YearsSinceLastPromotion'].value_counts()*100).plot.bar(color = 'blue')
# Out:
# Number of Employees by YearsSinceLastPromotion (in %):
#
# 0     39.52
# 1     24.29
# 2     10.82
# 3      3.54
# 4      4.15
# 5      3.06
# 6      2.18
# 7      5.17
# 8      1.22
# 9      1.16
# 10     0.41
# 11     1.63
# 12     0.68
# 13     0.68
# 14     0.61
# 15     0.88
# Name: YearsSinceLastPromotion, dtype: float64
#
# Attrition rate by YearsSinceLastPromotion:
#
# 0     18.93
# 1     13.73
# 2     16.98
# 3     17.31
# 4      8.20
# 5      4.44
# 6     18.75
# 7     21.05
# 8       NaN
# 9     23.53
# 10    16.67
# 11     8.33
# 12      NaN
# 13    20.00
# 14    11.11
# 15    23.08
# Name: YearsSinceLastPromotion, dtype: float64

# %% [markdown]
# ### Employees who have not been promoted for long are more likely to quit

# %%
data['Attrition'] = data['Attrition'].map({'Yes': 1, 'No': 0})

data['Income_band'] = pd.qcut(data['MonthlyIncome'], 4)

data[['Income_band', 'Attrition']].groupby(['Income_band'], as_index=False).mean().sort_values(by='Income_band', ascending=True)
# Out:
#             Income_band  Attrition
# 0  (10089.999, 29110.0]   0.181572
# 1    (29110.0, 49190.0]   0.142077
# 2    (49190.0, 83800.0]   0.187500
# 3   (83800.0, 199990.0]   0.133515
